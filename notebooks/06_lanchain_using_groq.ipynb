# %%
print("Jai Gajanan")
# Out:
# Jai Gajanan

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
res = llm.invoke("Explain Reverse Proxy.")

# %%
print(res.content)
# Out:
# ## Reverse Proxy – What It Is and Why It Matters
#
# A **reverse proxy** is a server that sits in front of one or more **origin (backend) servers** and forwards client requests to them. From the client’s point of view, the reverse proxy *is* the server that answers the request; the actual application servers are hidden behind it.
#
# | Perspective | Proxy Type | Typical Position |
# |-------------|------------|------------------|
# | **Forward proxy** (aka “proxy”) | Client → Proxy → Internet | Sits **in front of the client**; used to hide the client’s IP, enforce policies, cache outbound traffic. |
# | **Reverse proxy** | Client → **Reverse proxy** → Backend(s) | Sits **in front of the server(s)**; used to hide the server’s details, balance load, add security, etc. |
#
# ---
#
# ## Core Functions of a Reverse Proxy
#
# | Function | What It Does | Why It’s Useful |
# |----------|--------------|-----------------|
# ...
